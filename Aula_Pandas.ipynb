# %% [markdown]
# <a href="https://colab.research.google.com/github/npto04/pandas/blob/main/Aula_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Importação de biblioteca(s)

# %%
pip install pandera
# Out:
# ...
#      |████████████████████████████████| 197 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 10.9 MB 47.4 MB/s
# ...

# %%
import pandas as pd
import pandera as pa
import numpy as np
# import

# %% [markdown]
# ## Ler Dataset ( Multiplas fontes)

# %%
df = pd.read_csv("https://storage.googleapis.com/dados_brutos_soulcode/original/ocorrencia.csv",sep=";",parse_dates=['ocorrencia_dia'],dayfirst=True)

# %%
#df.info()
df
# Out:
#       codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0                 52242               52242               52242
# 1                 45331               45331               45331
# 2                 45333               45333               45333
# 3                 45401               45401               45401
# 4                 45407               45407               45407
# ...                 ...                 ...                 ...
# 5162              80458               80458               80458
# 5163              80452               80452               80452
# 5164              80457               80457               80457
# 5165              80460               80460               80460
# 5166              80467               80467               80467
#
#       codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0                  52242               52242                INCIDENTE
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                          int64
# codigo_ocorrencia1                         int64
# codigo_ocorrencia2                         int64
# codigo_ocorrencia3                         int64
# codigo_ocorrencia4                         int64
# ocorrencia_classificacao                  object
# ocorrencia_latitude                       object
# ocorrencia_longitude                      object
# ocorrencia_cidade                         object
# ocorrencia_uf                             object
# ocorrencia_pais                           object
# ocorrencia_aerodromo                      object
# ocorrencia_dia                    datetime64[ns]
# ocorrencia_hora                           object
# investigacao_aeronave_liberada            object
# investigacao_status                       object
# divulgacao_relatorio_numero               object
# divulgacao_relatorio_publicado            object
# divulgacao_dia_publicacao                 object
# ...

# %%
df.head()
#df.tail()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
# 4              45407               45407               45407
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                 ACIDENTE
# 4               45407               45407                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN      PORTO ALEGRE            RS
# ...

# %%
df.ocorrencia_classificacao.is_unique
# Out:
# False

# %% [markdown]
# ##Pré analise dos dados

# %% [markdown]
# Dropando colunas não utilizáveis e renomeando no dataframe

# %%
df.drop(['codigo_ocorrencia1','codigo_ocorrencia2','codigo_ocorrencia3','codigo_ocorrencia4','ocorrencia_latitude','ocorrencia_longitude'],axis=1,inplace=True)

# %%
df.drop(['ocorrencia_pais','divulgacao_relatorio_numero','divulgacao_relatorio_publicado','divulgacao_dia_publicacao'],axis=1,inplace=True)

# %%
df.rename(columns={'ocorrencia_cidade':'cidade','ocorrencia_uf':'uf','ocorrencia_aerodromo':'aerodromo','ocorrencia_dia':'data','ocorrencia_hora':'horario','investigacao_aeronave_liberada':'liberado','investigacao_status':'status','total_aeronaves_envolvidas':'total_aeronaves','ocorrencia_saida_pista':'saida_pista'},inplace=True)

# %% [markdown]
# ## Limpeza de dados

# %%
df.head(2)
# Out:
#    codigo_ocorrencia ocorrencia_classificacao        cidade  uf aerodromo  \
# 0              52242                INCIDENTE  PORTO ALEGRE  RS      SBPA
# 1              45331                 ACIDENTE     GUARULHOS  SP      SBGR
#
#         data   horario liberado      status  total_recomendacoes  \
# 0 2012-01-05  20:27:00      ***  FINALIZADA                    0
# 1 2012-01-06  13:44:00      SIM  FINALIZADA                    3
#
#    total_aeronaves saida_pista
# 0                1         NÃO
# 1                1         NÃO

# %%
sorted(pd.unique(df['uf']))
# Out:
# ['***',
#  'AC',
#  'AL',
#  'AM',
#  'AP',
#  'BA',
#  'CE',
#  'DF',
#  'ES',
#  'GO',
#  'MA',
#  'MG',
#  'MS',
#  'MT',
#  'PA',
#  'PB',
#  'PE',
#  'PI',
#  'PR',
#  'RJ',
#  'RN',
#  'RO',
#  'RR',
#  'RS',
#  'SC',
#  'SE',
#  'SP',
#  'TO']

# %% [markdown]
# ```
# # Inconsistencias encontradas ['***'] na coluna uf
# ['###!','####','****','*****'] na Coluna aerodromo
# ['***'] na coluna aeronave_liberada
#
# A verificar na coluna ocorrencia_uf
#  '5JTI',
#  '9PAA',
#  '9PBS',
#  '9PFC',
#  '9PFX',
#  '9PHD',
#  '9PSD',
# ```

# %%
#backup do dataframe original
df2 = df.copy()

# %%
df.replace(['***','###!','####','****','*****'],np.nan,inplace=True)

# %% [markdown]
# ##Tratamento de dados

# %% [markdown]
# Validação de dados

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# ocorrencia_classificacao       0
# cidade                         0
# uf                             2
# aerodromo                   1905
# data                           0
# horario                        1
# liberado                    1778
# status                       257
# total_recomendacoes            0
# total_aeronaves                0
# saida_pista                    0
# dtype: int64

# %%
# criação do Schema de dados

schema = pa.DataFrameSchema(
    columns = {
        "codigo_ocorrencia":pa.Column(pa.Int),
        "ocorrencia_classificacao":pa.Column(pa.String),
        "cidade":pa.Column(pa.String),
        "uf":pa.Column(pa.String,pa.Check.str_length(2,2),nullable=True),
        "aerodromo":pa.Column(pa.String,pa.Check.str_length(4,4),nullable=True),
        "data":pa.Column(pa.DateTime),
        "horario":pa.Column(pa.String,pa.Check.str_matches(r'^([0-1]?[0-9]|[2][0-3]):([0-5][0-9]):([0-5][0-9])?$'),nullable=True),
        "liberado":pa.Column(pa.String,pa.Check.str_length(3,3),nullable=True),
        "status":pa.Column(pa.String,nullable=True),
        "total_recomendacoes":pa.Column(pa.Int),
        "total_aeronaves":pa.Column(pa.Int),
        "saida_pista":pa.Column(pa.String,pa.Check.str_length(3,3))

    }
)

# %%
#Validador do DataFrame baseado no Schema
schema.validate(df)
# Out:
#       codigo_ocorrencia ocorrencia_classificacao         cidade  uf aerodromo  \
# 0                 52242                INCIDENTE   PORTO ALEGRE  RS      SBPA
# 1                 45331                 ACIDENTE      GUARULHOS  SP      SBGR
# 2                 45333                 ACIDENTE         VIAMÃO  RS       NaN
# 3                 45401                 ACIDENTE  SÃO SEBASTIÃO  SP       NaN
# 4                 45407                 ACIDENTE       SÃO SEPÉ  RS       NaN
# ...                 ...                      ...            ...  ..       ...
# 5162              80458                 ACIDENTE          JATAÍ  GO       NaN
# 5163              80452                 ACIDENTE        MARACAÍ  SP       NaN
# 5164              80457          INCIDENTE GRAVE  NOVO HAMBURGO  RS      SSNH
# 5165              80460                INCIDENTE       CURITIBA  PR      SBBI
# 5166              80467                INCIDENTE      PETROLINA  PE      SBPL
#
# ...

# %%
df.dtypes
# Out:
# codigo_ocorrencia                    int64
# ocorrencia_classificacao            object
# cidade                              object
# uf                                  object
# aerodromo                           object
# data                        datetime64[ns]
# horario                             object
# liberado                            object
# status                              object
# total_recomendacoes                  int64
# total_aeronaves                      int64
# saida_pista                         object
# dtype: object

# %% [markdown]
# #Filtros

# %%
df.isna().sum()
# Out:
# codigo_ocorrencia              0
# ocorrencia_classificacao       0
# cidade                         0
# uf                             2
# aerodromo                   1905
# data                           0
# horario                        1
# liberado                    1778
# status                       257
# total_recomendacoes            0
# total_aeronaves                0
# saida_pista                    0
# dtype: int64

# %%
df.count()
# Out:
# codigo_ocorrencia           5167
# ocorrencia_classificacao    5167
# cidade                      5167
# uf                          5165
# aerodromo                   3262
# data                        5167
# horario                     5166
# liberado                    3389
# status                      4910
# total_recomendacoes         5167
# total_aeronaves             5167
# saida_pista                 5167
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5167 entries, 0 to 5166
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   codigo_ocorrencia         5167 non-null   int64
#  1   ocorrencia_classificacao  5167 non-null   object
#  2   cidade                    5167 non-null   object
#  3   uf                        5165 non-null   object
#  4   aerodromo                 3262 non-null   object
#  5   data                      5167 non-null   datetime64[ns]
#  6   horario                   5166 non-null   object
#  7   liberado                  3389 non-null   object
#  8   status                    4910 non-null   object
#  9   total_recomendacoes       5167 non-null   int64
#  10  total_aeronaves           5167 non-null   int64
#  11  saida_pista               5167 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(8)
# memory usage: 484.5+ KB

# %%
df.shape
# Out:
# (5167, 12)

# %%
#Filtro nulos , NA , NaN , NaT , etc
filtrosnulos = df.horario.isnull()
filtroufnulo = df.uf.isnull()
filtronuloaero = df.aerodromo.isna()

# %%
df.loc[filtronuloaero]
# Out:
#       codigo_ocorrencia ocorrencia_classificacao                 cidade  uf  \
# 2                 45333                 ACIDENTE                 VIAMÃO  RS
# 3                 45401                 ACIDENTE          SÃO SEBASTIÃO  SP
# 4                 45407                 ACIDENTE               SÃO SEPÉ  RS
# 5                 52243                INCIDENTE                UBATUBA  SP
# 8                 45391                 ACIDENTE  CONCEIÇÃO DAS ALAGOAS  MG
# ...                 ...                      ...                    ...  ..
# 5151              80446                 ACIDENTE           JACAREACANGA  PA
# 5155              80450                 ACIDENTE               DOURADOS  MS
# 5159              80455          INCIDENTE GRAVE             SANTA RITA  PB
# 5162              80458                 ACIDENTE                  JATAÍ  GO
# 5163              80452                 ACIDENTE                MARACAÍ  SP
#
# ...

# %%
filtro1 = df.ocorrencia_classificacao == 'INCIDENTE'
filtrosaida = df.saida_pista == 'NÃO'
df.loc[filtro1]
# Out:
#       codigo_ocorrencia ocorrencia_classificacao        cidade  uf aerodromo  \
# 0                 52242                INCIDENTE  PORTO ALEGRE  RS      SBPA
# 5                 52243                INCIDENTE       UBATUBA  SP       NaN
# 7                 45334                INCIDENTE         BELÉM  PA      SBBE
# 9                 52244                INCIDENTE    UBERLÂNDIA  MG      SBUL
# 11                52245                INCIDENTE  PORTO ALEGRE  RS      SBPA
# ...                 ...                      ...           ...  ..       ...
# 5157              80453                INCIDENTE      CAMPINAS  SP      SBKP
# 5160              80451                INCIDENTE        MANAUS  AM      SBEG
# 5161              80456                INCIDENTE     SÃO PAULO  SP      SBSP
# 5165              80460                INCIDENTE      CURITIBA  PR      SBBI
# 5166              80467                INCIDENTE     PETROLINA  PE      SBPL
#
# ...

# %%
df.loc[filtro1 & filtrosaida, ['cidade','saida_pista','uf']]
# Out:
#             cidade saida_pista  uf
# 0     PORTO ALEGRE         NÃO  RS
# 5          UBATUBA         NÃO  SP
# 7            BELÉM         NÃO  PA
# 9       UBERLÂNDIA         NÃO  MG
# 11    PORTO ALEGRE         NÃO  RS
# ...            ...         ...  ..
# 5156       MARINGÁ         NÃO  PR
# 5157      CAMPINAS         NÃO  SP
# 5160        MANAUS         NÃO  AM
# 5165      CURITIBA         NÃO  PR
# 5166     PETROLINA         NÃO  PE
#
# [2767 rows x 3 columns]

# %%
filtro2 = df.ocorrencia_classificacao.isin(['ACIDENTE','INCIDENTE'])
filtro3 = df.uf == 'RJ'

# %%
df.loc[filtro2 & filtro3]
# Out:
#       codigo_ocorrencia ocorrencia_classificacao                 cidade  uf  \
# 16                45693                INCIDENTE                  MACAÉ  RJ
# 29                45393                 ACIDENTE         RIO DE JANEIRO  RJ
# 40                45415                 ACIDENTE         RIO DE JANEIRO  RJ
# 44                45668                INCIDENTE  CAMPOS DOS GOYTACAZES  RJ
# 45                45682                INCIDENTE                  MACAÉ  RJ
# ...                 ...                      ...                    ...  ..
# 5044              80317                 ACIDENTE         RIO DE JANEIRO  RJ
# 5089              80399                INCIDENTE         RIO DE JANEIRO  RJ
# 5119              80410                INCIDENTE         RIO DE JANEIRO  RJ
# 5132              80438                INCIDENTE         RIO DE JANEIRO  RJ
# 5136              80430                INCIDENTE         RIO DE JANEIRO  RJ
#
# ...

# %%
filtroLetra = df.cidade.str[-2:] == 'IO'

# %%
df.loc[filtroLetra]
# Out:
#       codigo_ocorrencia ocorrencia_classificacao                 cidade  uf  \
# 75                45712                INCIDENTE              CABO FRIO  RJ
# 131               45685                INCIDENTE              CABO FRIO  RJ
# 264               45946                INCIDENTE              CABO FRIO  RJ
# 295               46197                INCIDENTE                 OSÓRIO  RS
# 318               46196                INCIDENTE                 OSÓRIO  RS
# 378               52063                INCIDENTE              CABO FRIO  RJ
# 515               46698                INCIDENTE              CABO FRIO  RJ
# 675               46859                 ACIDENTE      CORNÉLIO PROCÓPIO  PR
# 716               47063                INCIDENTE              CABO FRIO  RJ
# 746               49115                 ACIDENTE          VILA PROPÍCIO  GO
# 1321              52940                 ACIDENTE      QUARTO CENTENÁRIO  PR
# ...

# %%
filtrocontain = df.cidade.str.contains('MA|RIO')

# %%
df.loc[filtrocontain]
# Out:
#       codigo_ocorrencia ocorrencia_classificacao                   cidade  uf  \
# 12                45396          INCIDENTE GRAVE                   MARABÁ  PA
# 14                45447                INCIDENTE               RIO BRANCO  AC
# 16                45693                INCIDENTE                    MACAÉ  RJ
# 29                45393                 ACIDENTE           RIO DE JANEIRO  RJ
# 30                45397          INCIDENTE GRAVE           RIO DE JANEIRO  RJ
# ...                 ...                      ...                      ...  ..
# 5138              80428                 ACIDENTE  SANTA VITÓRIA DO PALMAR  RS
# 5153              80461                INCIDENTE                  MARINGÁ  PR
# 5156              80463                INCIDENTE                  MARINGÁ  PR
# 5160              80451                INCIDENTE                   MANAUS  AM
# 5163              80452                 ACIDENTE                  MARACAÍ  SP
#
# ...

# %%
filtro_ano = df.data.dt.year == 2021
filtro_mes = df.data.dt.month == 7
filtro_dia = (df.data.dt.day > 0) & (df.data.dt.day < 16 )
filtroSp = df.uf == "SP"

# %%
dfspmes = df.loc[filtro_ano & filtro_mes & filtro_dia &filtroSp]

# %%
dfspmes
# Out:
#       codigo_ocorrencia ocorrencia_classificacao             cidade  uf  \
# 4910              80169                INCIDENTE     RIBEIRÃO PRETO  SP
# 4914              80156                 ACIDENTE           CAMPINAS  SP
# 4916              80161                INCIDENTE          GUARULHOS  SP
# 4920              80184                INCIDENTE     RIBEIRÃO PRETO  SP
# 4922              80170                INCIDENTE          GUARULHOS  SP
# 4924              80178                INCIDENTE     RIBEIRÃO PRETO  SP
# 4927              80168                 ACIDENTE  BRAGANÇA PAULISTA  SP
# 4928              80174                INCIDENTE          SÃO PAULO  SP
# 4932              80186                INCIDENTE              BAURU  SP
# 4934              80187                INCIDENTE     RIBEIRÃO PRETO  SP
# 4936              80176                 ACIDENTE          BEBEDOURO  SP
#
#      aerodromo       data   horario liberado      status  total_recomendacoes  \
# ...

# %% [markdown]
# Group By

# %%
dfspmes.groupby(['aerodromo']).aerodromo.count()
# Out:
# aerodromo
# SBBP    1
# SBBU    1
# SBGR    2
# SBRP    4
# SBSP    1
# SDAM    1
# SDBB    1
# Name: aerodromo, dtype: int64

# %%
df.groupby(['ocorrencia_classificacao']).ocorrencia_classificacao.count()
# Out:
# ocorrencia_classificacao
# ACIDENTE           1667
# INCIDENTE          2809
# INCIDENTE GRAVE     691
# Name: ocorrencia_classificacao, dtype: int64

# %%
df.groupby(['ocorrencia_classificacao']).size()
# Out:
# ocorrencia_classificacao
# ACIDENTE           1667
# INCIDENTE          2809
# INCIDENTE GRAVE     691
# dtype: int64

# %%
df.groupby(['ocorrencia_classificacao']).size().sort_values(ascending=True)
# Out:
# ocorrencia_classificacao
# INCIDENTE GRAVE     691
# ACIDENTE           1667
# INCIDENTE          2809
# dtype: int64

# %%
df.groupby(['uf']).size().sort_values(ascending=False)
# Out:
# uf
# SP    1261
# MG     499
# PR     431
# RJ     402
# RS     327
# MT     276
# GO     268
# PA     261
# AM     207
# BA     183
# SC     167
# MS     158
# DF     106
# PE      86
# CE      78
# ES      73
# MA      59
# RR      54
# AC      49
# TO      46
# RO      43
# PI      38
# AL      28
# PB      22
# RN      17
# SE      14
# AP      12
# dtype: int64

# %%
df.groupby(['uf','cidade']).size().sort_values(ascending=False)
# Out:
# uf  cidade
# RJ  RIO DE JANEIRO                 247
# SP  SÃO PAULO                      247
# MG  BELO HORIZONTE                 171
# SP  CAMPINAS                       167
#     GUARULHOS                      129
#                                   ...
# MT  NOSSA SENHORA DO LIVRAMENTO      1
#     NOVA BRASILÂNDIA                 1
#     NÃO IDENTIFICADA                 1
#     PEIXOTO DE AZEVEDO               1
# TO  RECURSOLÂNDIA                    1
# Length: 1066, dtype: int64

# %% [markdown]
# Group by sem descarte

# %%
dfsp = df.loc[filtroSp & filtro_mes]

# %%
dfsp
# Out:
#       codigo_ocorrencia ocorrencia_classificacao             cidade  uf  \
# 307               46073                INCIDENTE          GUARULHOS  SP
# 313               46161                INCIDENTE          GUARULHOS  SP
# 316               46092                 ACIDENTE            BOITUVA  SP
# 317               46105                INCIDENTE           CAMPINAS  SP
# 320               46159                INCIDENTE          SÃO PAULO  SP
# ...                 ...                      ...                ...  ..
# 4953              80199                INCIDENTE            ATIBAIA  SP
# 4954              80200          INCIDENTE GRAVE  BRAGANÇA PAULISTA  SP
# 4955              80201                INCIDENTE           CAÇAPAVA  SP
# 4957              80234                INCIDENTE          SÃO PAULO  SP
# 4958              80208                INCIDENTE          SÃO PAULO  SP
#
#      aerodromo       data   horario liberado      status  total_recomendacoes  \
# ...

# %%
dfsp.groupby(['aerodromo'],dropna=False).size().sort_values(ascending=False)
# Out:
# aerodromo
# NaN     30
# SBMT    12
# SBKP    11
# SBGR    10
# SBRP     8
# SBSP     6
# SBJD     4
# SBBU     3
# SBSJ     3
# SDBB     3
# SBBP     3
# SDVH     3
# SDPW     3
# SDTB     2
# SDAM     2
# SDUB     2
# SNBA     1
# SJBM     1
# SILT     1
# SIJG     1
# SDTF     1
# SBAE     1
# SDPY     1
# SDNI     1
# SDIP     1
# SDIO     1
# SDCO     1
# SDAI     1
# SBGW     1
# SDEM     1
# dtype: int64

# %%
dfsp.groupby(['aerodromo']).size().sort_values(ascending=False).plot.bar(figsize=(12,8),xlabel='classificao aerodromo',ylabel='Qtd . Ocorrencias')

# %%
df.groupby(['uf'],dropna=False).size().sort_values(ascending=False).plot.bar(figsize=(10,6),xlabel='Tipos de Ocorrencia',ylabel='Num. Ocorrencias')

# %%
df.groupby(['liberado']).size().sort_values(ascending=False).plot.area(label='teste')

# %% [markdown]
# ## LOAD(CARREGAMENTO) de dados

# %%
df.to_csv('ocorrencias_cenipa_2012_2021_new.csv', index=False)

# %%
df.tail(3)
# Out:
#       codigo_ocorrencia ocorrencia_classificacao         cidade  uf aerodromo  \
# 5164              80457          INCIDENTE GRAVE  NOVO HAMBURGO  RS      SSNH
# 5165              80460                INCIDENTE       CURITIBA  PR      SBBI
# 5166              80467                INCIDENTE      PETROLINA  PE      SBPL
#
#            data   horario liberado      status  total_recomendacoes  \
# 5164 2021-12-31  11:59:00      SIM  FINALIZADA                    0
# 5165 2021-12-31  15:12:00      SIM  FINALIZADA                    0
# 5166 2021-12-31  20:30:00      SIM  FINALIZADA                    0
#
#       total_aeronaves saida_pista
# 5164                1         NÃO
# 5165                1         NÃO
# 5166                1         NÃO

# %%
df.loc[5166]
# Out:
# codigo_ocorrencia                         80467
# ocorrencia_classificacao              INCIDENTE
# cidade                                PETROLINA
# uf                                           PE
# aerodromo                                  SBPL
# data                        2021-12-31 00:00:00
# horario                                20:30:00
# liberado                                    SIM
# status                               FINALIZADA
# total_recomendacoes                           0
# total_aeronaves                               1
# saida_pista                                 NÃO
# Name: 5166, dtype: object

# %%
df.loc[80467]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     384                 try:
# --> 385                     return self._range.index(new_key)
#     386                 except ValueError as err:
#
# ValueError: 80467 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-58937cdbc467> in <module>()
# ----> 1 df.loc[80467]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ...

# %%
df.codigo_ocorrencia.is_unique

# %%
df.set_index('codigo_ocorrencia',inplace=True)

# %%
df.tail(3)

# %%
df.reset_index(inplace=True)

# %%
df

# %%
df.to_csv('marcelo.csv')

# %%
dfload = pd.read_csv('/content/ocorrencias_cenipa_2012_2021.csv',sep=',')
dfload

# %% [markdown]
# ## CONECTOR MONGO + PANDAS

# %%
pip install pymongo[srv]

# %%
#importação bib mongoDB
import pymongo
from pymongo import MongoClient

# %%
username = input('username')
password = input('password')
url = f"mongodb+srv://{username}:{password}@soulteste.eley5.mongodb.net/Soulteste"

# %%
#conector Mongo Atlas

client = pymongo.MongoClient(url)

# %%
# DataBase utilizado
db = client['aulamongo']
# Coleção utilizada
datacolec = db.cenipaa
teste = db.pazzetto

# %%
df.fillna(0)

# %%
df

# %%
#Carregar DataFrame para Mongo DB
df_dici = df.to_dict("records")
#inserir na coleção
teste.insert_many(df_dici)

# %%
#Extraindo direto do mongo Atlas
extrator = datacolec.find({})
marlon = pd.DataFrame(list(extrator))

# %%
marlon

# %%
aeronull = dfsp.aerodromo.isna()

# %%
analise = dfsp.loc[aeronull]

# %%
analise.groupby(['cidade']).size().sort_values(ascending=False)

# %%
df.loc[:,'ocorrencia_teste'] = 'BIS'

# %%
df.drop(['divulgacao_relatorio_numero','divulgacao_relatorio_publicado','divulgacao_dia_publicacao'],axis=1,inplace=True)

# %%
df.drop(['ocorrencia_latitude','ocorrencia_longitude'],axis=1,inplace=True)

# %%
df.loc[0:2]

# %%
sorted(pd.unique(df['total_aeronaves_envolvidas']))

# %%
sorted(pd.unique(df['ocorrencia_aerodromo']))

# %%
df['bkp_ocorrencia_aerodromo'] = df.ocorrencia_aerodromo

# %%
df.head(2)

# %%
df2 = df.copy()

# %%
df2

# %%
df.drop('bkp_ocorrencia_aerodromo',axis=1,inplace=True)

# %%
df2 = df.copy()

# %%
df2.head(5)

# %%
df2.loc[df2.uf == 'SP',['status']]

# %%
df2.loc[df2.uf == 'RS']

# %%
df2.head(3)

# %%
filtrouf = df2.uf == 'SP'
filtroclass = df2.ocorrencia_classificacao == 'INCIDENTE GRAVE'
filtrocidade = df2.cidade == 'SÃO PAULO'

# %%
dfreduzido = df2.loc[filtrouf & filtroclass & filtrocidade]

# %%
dfreduzido

# %%
filtrors = df2.uf == 'RS'
filtrorj = df2.uf == 'RJ'

# %%
df2.loc[filtrors | filtrorj]

# %%
filtro2020 = df2.data.dt.year == 2020

# %%
dados2020 = df2.loc[filtro2020]

# %%
dados2020.to_csv('dados2020.csv')

# %%
df2.to_csv('completao.csv')
